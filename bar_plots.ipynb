# %%
import matplotlib.pyplot as plt

# Data
segments = ['Client Front Freezed', 'Server Side Freezed', 'Server Side Unfreezed', 'Client Back Unfreezed']
split_names = ['S-1', 'S-2', 'S-3', 'S-4']
client_front_freezed = [99536, 99536, 99536, 99536]
server_side_freezed = [673536, 673536, 673536, 673536]
server_side_unfreezed = [10493440, 5772800, 2099712, 919040]
client_back_unfreezed = [95130, 4725770, 8398858, 9579530]

# Plotting
bar_width = 0.2
index = range(len(split_names))
opacity = 0.8

fig, ax = plt.subplots()

for i, (segment, data) in enumerate(zip(segments, [client_front_freezed, server_side_freezed, server_side_unfreezed, client_back_unfreezed])):
    plt.bar([x + i * bar_width for x in index], data, bar_width,
            alpha=opacity,
            label=segment)

plt.xlabel('Splits')
plt.ylabel('Number of Parameters')
#plt.title('Parameter Distribution Across Model Segments for ResNet-18 Splits')
plt.xticks([i + bar_width for i in index], spimport matplotlib.pyplot as plt

# Data from the table
segments = ['S-1', 'S-2', 'S-3', 'S-4']
client_front = [9536, 9536, 9536, 9536]
server_side = [673536, 673536, 673536, 673536]
server_unfreezed = [10493440, 5772800, 2099712, 919040]
client_unfreezed = [5130, 4725770, 8398858, 9579530]

# Creating the bar graph
x = range(len(segments))
width = 0.2

fig, ax = plt.subplots(figsize=(10, 6))
bar1 = ax.bar(x, client_front, width, label='Client Front')
bar2 = ax.bar(x, server_side, width, label='Server Side', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[client + server for client, server in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[client + server + server_unfreezed for client, server, server_unfreezed in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Segments')
ax.set_ylabel('Number of Parameters')
ax.set_title('Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
ax.legend()

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('parameter_distribution.pdf')
plt.show()
lit_names)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
#   Input In [1]
#     plt.xticks([i + bar_width for i in index], spimport matplotlib.pyplot as plt
#                                                         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# Data from the table
segments = ['S-1', 'S-2', 'S-3', 'S-4']
client_front = [99536, 99536, 99536, 99536]
server_side = [673536, 673536, 673536, 673536]
server_unfreezed = [10493440, 5772800, 2099712, 919040]
client_unfreezed = [205130, 4725770, 8398858, 9579530]

# Creating the bar graph
x = range(len(segments))
width = 0.5

fig, ax = plt.subplots(figsize=(6, 6))
bar1 = ax.bar(x, client_front, width, label='Client Front Freezed')
bar2 = ax.bar(x, server_side, width, label='Server Side Freezed', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[client + server for client, server in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[client + server + server_unfreezed for client, server, server_unfreezed in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Split', fontsize=16)
ax.set_ylabel('Number of Parameters', fontsize=16)
#ax.set_title('Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
#ax.legend(loc='upper right')
ax.legend(loc='upper right', bbox_to_anchor=(1.07, 1.17)) 

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('parameter_distribution.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table
segments = ['S-1', 'S-2', 'S-3', 'S-4']
client_front = [0.099536, 0.099536, 0.099536, 0.099536]
server_side = [0.673536, 0.673536, 0.673536, 0.673536]
server_unfreezed = [10.493440, 5.772800, 2.099712, 0.919040]
client_unfreezed = [0.205130, 4.725770, 8.398858, 9.579530]

# Creating the bar graph
x = range(len(segments))
width = 0.5

fig, ax = plt.subplots(figsize=(6, 5))
bar1 = ax.bar(x, client_front, width, label='Client Front Freezed')
bar2 = ax.bar(x, server_side, width, label='Server Side Freezed', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[client + server for client, server in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[client + server + server_unfreezed for client, server, server_unfreezed in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Split', fontsize=14)
ax.set_ylabel('Number of Parameters(in millions)', fontsize=13)
#ax.set_title('Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
#ax.legend(loc='upper right')
ax.legend(loc='upper right', bbox_to_anchor=(1.02, 1.3)) 

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('parameter_distribution.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table
segments = ['S-1', 'S-2', 'S-3', 'S-4','','']
client_front = [0.099536, 0.099536, 0.099536, 0.099536,0,0]
server_side = [0.673536, 0.673536, 0.673536, 0.673536,0,0]
server_unfreezed = [10.493440, 5.772800, 2.099712, 0.919040,0,0]
client_unfreezed = [0.205130, 4.725770, 8.398858, 9.579530,0,0]

# Creating the bar graph
x = range(len(segments))
width = 0.5

fig, ax = plt.subplots(figsize=(7, 4))
bar1 = ax.bar(x, client_front, width, label='Client Front Freezed')
bar2 = ax.bar(x, server_side, width, label='Server Side Freezed', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[client + server for client, server in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[client + server + server_unfreezed for client, server, server_unfreezed in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Split', fontsize=14)
ax.set_ylabel('Number of Parameters(in millions)', fontsize=13)
#ax.set_title('Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
#ax.legend(loc='upper right')
ax.legend(loc='upper right', bbox_to_anchor=(1.01, 1.005)) 

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('parameter_distribution.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table
segments = ['S-1', 'S-2', 'S-3', 'S-4','','']
client_front = [0.063412, 0.063412, 0.285046, 0.063412,0,0]
server_side = [1.107268, 1.107268, 0.885634, 1.107268,0,0]
server_unfreezed = [3.463300, 3.601734, 3.636392, 2.688770,0,0]
client_unfreezed = [0.174937, 0.036503, 0.001845, 0.949467,0,0]

# Creating the bar graph0.
x = range(len(segments))
width = 0.5

fig, ax = plt.subplots(figsize=(7, 4))
bar1 = ax.bar(x, client_front, width, label='Client Front Freezed')
bar2 = ax.bar(x, server_side, width, label='Server Side Freezed', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[client + server for client, server in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[client + server + server_unfreezed for client, server, server_unfreezed in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Split', fontsize=14)
ax.set_ylabel('Number of Parameters(in millions)', fontsize=13)
#ax.set_title('Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
#ax.legend(loc='upper right')
ax.legend(loc='upper right', bbox_to_anchor=(1.01, 1.005)) 

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('parameter_distribution.pdf')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Client Front Freezed': [63412, 63412, 285046, 63412],
        'Server Side Freezed': [1107268, 1107268, 885634, 1107268],
        'Server Side Unfreezed ': [3463300, 3601734, 3636392, 2688770],
        'Client Back Unfreezed': [174937, 36503, 1845, 949467]}
data = {k:[x/1e6 for x in v] for k,v in data.items()}
index = ['split 1', 'split 2', 'split 3', 'split 4']
df = pd.DataFrame(data,index=index)

ax = df.plot(kind='bar', stacked=True, width=0.5, figsize=(10, 6))

for label in ax.get_xticklabels():
    label.set_rotation(0)
plt.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))
plt.ylabel('Number of Parameters (in Millions)', fontsize=14)

plt.savefig("unet_params.pdf", dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt

# Data from the table
segments = ['S-1', 'S-2', 'S-3', 'S-4']
client_front = [0.099536, 0.099536, 0.099536, 0.099536,0.099536, 0.099536, 0.099536, 0.099536,0.099536, 0.099536]
server_side = [0.673536, 0.673536, 0.673536, 0.673536,0.673536, 0.673536, 0.673536, 0.673536,0.673536, 0.673536]
server_unfreezed = [10.493440, 10.493440, 10.493440, 10.493440,10.493440, 10.493440, 10.493440, 10.493440,10.493440, 10.493440, 2.099712]
client_unfreezed = [0.005130,0.033482,0.0387300,0.079946,0.154058,0.273930,0.295690,0.598986,1.606410,3.220426,8.398858]






# Creating the bar graph
x = range(len(segments))
width = 0.5

fig, ax = plt.subplots(figsize=(8, 8))
bar1 = ax.bar(x, client_front, width, label='Client Front Freezed')
bar2 = ax.bar(x, server_side, width, label='Server Side Freezed', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[client + server for client, server in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[client + server + server_unfreezed for client, server, server_unfreezed in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Split', fontsize=16)
ax.set_ylabel('Number of Parameters in millions', fontsize=14)
#ax.set_title('Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
#ax.legend(loc='upper right')
ax.legend(loc='upper right', bbox_to_anchor=(1.07, 1.17)) 

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('parameter_distribution.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 20>()
#      17 width = 0.5
#      19 fig, ax = plt.subplots(figsize=(8, 8))
# ---> 20 bar1 = ax.bar(x, client_front, width, label='Client Front Freezed')
#      21 bar2 = ax.bar(x, server_side, width, label='Server Side Freezed', bottom=client_front)
#      22 bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[client + server for client, server in zip(client_front, server_side)])
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt

# Updated data with 11 elements
segments = ['S-1', 'C-1', 'C-2', 'C-3', 'C-4', 'C-5', 'C-6', 'C-7', 'C-8', 'C-9', 'S-3']
client_front = [0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536]
server_side = [0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536]
server_unfreezed = [10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 2.099712]
client_unfreezed = [0.030130, 0.035482, 0.0407300, 0.079946, 0.154058, 0.273930, 0.295690, 0.598986, 1.606410, 3.220426, 8.398858]

# Creating the bar graph
x = range(len(segments))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 6))

bar1 = ax.bar(x, client_front, width, label='Client Front')
bar2 = ax.bar(x, server_side, width, label='Server Side', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[cf + ss for cf, ss in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[cf + ss + su for cf, ss, su in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Split', fontsize=16)
ax.set_ylabel('Number of Parameters in millions', fontsize=16)
#ax.set_title('Updated Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
plt.xticks(rotation=45)  # Rotating x-axis labels for better readability
plt.legend(loc='upper right', bbox_to_anchor=(1.09, 1))

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('custom_parameter_distribution.pdf', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Updated data with 11 elements
segments = ['S-1', 'C-1', 'C-2', 'C-3', 'C-4', 'C-5', 'C-6', 'C-7', 'C-8', 'C-9', 'S-3']
client_front = [0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536]
server_side = [0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536]
server_unfreezed = [10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 2.099712]
client_unfreezed = [0.030130, 0.035482, 0.0407300, 0.079946, 0.154058, 0.273930, 0.295690, 0.598986, 1.606410, 3.220426, 8.398858]

# Creating the bar graph
x = range(len(segments))
width = 0.35

fig, ax = plt.subplots(figsize=(7, 5))

bar1 = ax.bar(x, client_front, width, label='Client Front')
bar2 = ax.bar(x, server_side, width, label='Server Side', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[cf + ss for cf, ss in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[cf + ss + su for cf, ss, su in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Split', fontsize=14)
ax.set_ylabel('Number of Parameters(in millions)', fontsize=14)
#ax.set_title('Updated Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
plt.xticks(rotation=45)  # Rotating x-axis labels for better readability
plt.legend(loc='upper right', bbox_to_anchor=(0.5, 1.01))

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('custom_parameter_distribution.pdf', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Updated data with 11 elements
segments = ['S-1', 'C-1', 'C-2', 'C-3', 'C-4', 'C-5', 'C-6', 'C-7', 'C-8', 'C-9', 'S-3','','','','']
client_front = [0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536, 0.099536,0,0,0,0]
server_side = [0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536, 0.673536,0,0,0,0]
server_unfreezed = [10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 10.493440, 2.099712,0,0,0,0]
client_unfreezed = [0.030130, 0.035482, 0.0407300, 0.079946, 0.154058, 0.273930, 0.295690, 0.598986, 1.606410, 3.220426, 8.398858,0,0,0,0]

# Creating the bar graph
x = range(len(segments))
width = 0.35

fig, ax = plt.subplots(figsize=(7, 4))

bar1 = ax.bar(x, client_front, width, label='Client Front')
bar2 = ax.bar(x, server_side, width, label='Server Side', bottom=client_front)
bar3 = ax.bar(x, server_unfreezed, width, label='Server Side Unfreezed', bottom=[cf + ss for cf, ss in zip(client_front, server_side)])
bar4 = ax.bar(x, client_unfreezed, width, label='Client Back Unfreezed', bottom=[cf + ss + su for cf, ss, su in zip(client_front, server_side, server_unfreezed)])

# Adding labels, title, and legend
ax.set_xlabel('Split', fontsize=14)
ax.set_ylabel('Number of Parameters(in millions)', fontsize=14)
#ax.set_title('Updated Parameter Distribution Across ResNet-18 Model Splits')
ax.set_xticks(x)
ax.set_xticklabels(segments)
plt.xticks(rotation=45)  # Rotating x-axis labels for better readability
plt.legend(loc='upper right', bbox_to_anchor=(1.05, 1.07))

# Saving the graph as a PDF file
plt.tight_layout()
plt.savefig('custom_parameter_distribution.pdf', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for class count in each client
data = {
    "Client-1": [2279, 3363, 2245, 606, 923, 97, 87, 330],
    "Client-2": [20, 2977, 2, 0, 96, 23, 45, 0],
    "Client-3": [533, 1470, 174, 20, 379, 40, 64, 11],
    "Client-4": [276, 649, 223, 86, 406, 20, 3, 144],
    "Client-5": [166, 349, 0, 0, 140, 0, 0, 0],
    "Client-6": [58, 276, 5, 0, 6, 4, 2, 0]
}

# Classes
classes = ["Class-0", "Class-1", "Class-2", "Class-3", "Class-4", "Class-5", "Class-6", "Class-7"]

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))

for client, counts in data.items():
    for i, count in enumerate(counts):
        ax.scatter(i, count, s=count*0.5, label=client if i == 0 else "_")

ax.set_xticks(range(len(classes)))
ax.set_xticklabels(classes)
ax.set_xlabel('Classes')
ax.set_ylabel('Count')
ax.legend(title='Clients', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title('Class Counts in Different Clients')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for class count in each client
data = {
    "Client-1": [2279, 3363, 2245, 606, 923, 97, 87, 330],
    "Client-2": [20, 2977, 2, 0, 96, 23, 45, 0],
    "Client-3": [533, 1470, 174, 20, 379, 40, 64, 11],
    "Client-4": [276, 649, 223, 86, 406, 20, 3, 144],
    "Client-5": [166, 349, 0, 0, 140, 0, 0, 0],
    "Client-6": [58, 276, 5, 0, 6, 4, 2, 0]
}

# Classes
classes = ["Class-0", "Class-1", "Class-2", "Class-3", "Class-4", "Class-5", "Class-6", "Class-7"]

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))

for i, (client, counts) in enumerate(data.items()):
    for j, count in enumerate(counts):
        ax.scatter(i, j, s=count*0.5, label=client if j == 0 else "_")

ax.set_yticks(range(len(classes)))
ax.set_yticklabels(classes)
ax.set_ylabel('Classes')
ax.set_xticks(range(len(data)))
ax.set_xticklabels(data.keys())
ax.set_xlabel('Clients')
ax.legend(title='Clients', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title('Class Counts in Different Clients')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for class count in each client
data = {
    "Client-1": [2279, 3363, 2245, 606, 923, 97, 87, 330],
    "Client-2": [20, 2977, 2, 0, 96, 23, 45, 0],
    "Client-3": [533, 1470, 174, 20, 379, 40, 64, 11],
    "Client-4": [276, 649, 223, 86, 406, 20, 3, 144],
    "Client-5": [166, 349, 0, 0, 140, 0, 0, 0],
    "Client-6": [58, 276, 5, 0, 6, 4, 2, 0]
}

# Classes
classes = ["Class-0", "Class-1", "Class-2", "Class-3", "Class-4", "Class-5", "Class-6", "Class-7"]
class_colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray']  # Assign colors to classes

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))

for i, (client, counts) in enumerate(data.items()):
    for j, count in enumerate(counts):
        ax.scatter(i, j, s=count*0.5, color=class_colors[j], label=classes[j] if i == 0 else "_")

ax.set_yticks(range(len(classes)))
ax.set_yticklabels(classes)
ax.set_ylabel('Classes')
ax.set_xticks(range(len(data)))
ax.set_xticklabels(data.keys())
ax.set_xlabel('Clients')
ax.legend(title='Classes', bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.title('Class Counts in Different Clients')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for class count in each client
data = {
    "Client-1": [2279, 3363, 2245, 606, 923, 97, 87, 330],
    "Client-2": [20, 2977, 2, 0, 96, 23, 45, 0],
    "Client-3": [533, 1470, 174, 20, 379, 40, 64, 11],
    "Client-4": [276, 649, 223, 86, 406, 20, 3, 144],
    "Client-5": [166, 349, 0, 0, 140, 0, 0, 0],
    "Client-6": [58, 276, 5, 0, 6, 4, 2, 0]
}

# Classes
classes = ["Class-0", "Class-1", "Class-2", "Class-3", "Class-4", "Class-5", "Class-6", "Class-7"]
class_colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray']  # Assign colors to classes

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))

for i, (client, counts) in enumerate(data.items()):
    for j, count in enumerate(counts):
        ax.scatter(i, j, s=count*0.5, color=class_colors[j], label=classes[j] if i == 0 else "_")

ax.set_yticks(range(len(classes)))
ax.set_yticklabels(classes)
ax.set_ylabel('Target Class', fontsize=16)
ax.set_xticks(range(len(data)))
ax.set_xticklabels(data.keys())
ax.set_xlabel('Client', fontsize=16)
ax.legend(title='Classes', bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.title('Class Counts in Different Clients')
plt.tight_layout()

# Save as PDF and PNG
plt.savefig('class_counts_plot.pdf', format='pdf')
plt.savefig('class_counts_plot.png', format='png')

plt.show()
